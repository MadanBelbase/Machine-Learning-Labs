# %%
# %pip install numpy matplotlib scikit-learn tensorflow torch

import numpy as np
import matplotlib.pyplot as plt

# Reproducibility — fix seeds so results are the same on every run
SEED = 42
np.random.seed(SEED)

print("NumPy:", np.__version__)
# Out:
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.7/259.7 MB 388.5 kB/s  0:10:56 eta 0:00:010:00:16
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 597.9 kB/s  0:00:38 eta 0:00:010:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 631.3 kB/s  0:00:19a 0:00:010:00:01:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 373.6 kB/s  0:00:152.9 kB/s eta 0:00:01:05
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 286.8 kB/s  0:00:17a 0:00:01m eta 0:00:02
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 719.0 kB/s  0:00:023.4 kB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 412.2 kB/s  0:01:07 eta 0:00:010:00:02
# ...
#   Attempting uninstall: typing-extensions━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/18 [flatbuffers]
# ...

# %%
class Perceptron:
    """A single-layer perceptron with the classic step-function learning rule."""

    def __init__(self, learning_rate=0.1, n_iters=20):
        self.lr = learning_rate
        self.n_iters = n_iters
        self.weights = None
        self.bias = None
        self.errors_ = []      # misclassifications per epoch (for the learning curve)

    def _activation(self, z):
        """Heaviside step function."""
        return np.where(z >= 0, 1, 0)

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0.0
        self.errors_ = []

        for _ in range(self.n_iters):
            errors = 0
            for idx in range(n_samples):
                # 1) forward pass
                z = np.dot(X[idx], self.weights) + self.bias
                y_pred = self._activation(z)

                # 2) perceptron learning rule
                update = self.lr * (y[idx] - y_pred)
                self.weights += update * X[idx]
                self.bias += update

                errors += int(update != 0.0)
            self.errors_.append(errors)
        return self

    def predict(self, X):
        z = np.dot(X, self.weights) + self.bias
        return self._activation(z)
